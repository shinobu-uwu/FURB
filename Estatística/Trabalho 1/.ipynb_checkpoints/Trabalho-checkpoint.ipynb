# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Questão 1 (A)
dados_cont = np.array([1_280, 5_320, 4_390, 2_100, 1_240, 3_060, 4_770, 1_050, 1_320, 360, 3_330, 3_380, 530, 3_350,
                       960, 1_120, 2_120, 3_150, 5_700, 5_220, 2_700, 2_730, 1_670, 510, 240, 340, 1_000, 960,
                       540, 3_870, 1_250, 2_400, 450, 2_250, 2_320, 2_400, 500, 1_850, 2_460, 5_850, 100, 5_770, 3_150,
                       1_890, 396, 1_419, 2_109])

dados = pd.DataFrame.from_dict({'Comprimento total das ruas dentro de uma subdivisão': dados_cont})
plt.hist(dados)
plt.show()

# %%
# Questão 1 (B)
print(f"Média: {dados.mean()[0]}")
print(f"Mediana {dados.median()[0]}")
print(f"Primeiro quartil: {np.percentile(dados_cont, 25)}")
print(f"Segundo quartil: {np.percentile(dados_cont, 50)}")
print(f"Terceiro quartil: {np.percentile(dados_cont, 75)}")

# %%
# Questão 1 (C)
plt.boxplot(dados)
plt.show()

# %%
# Questão 1 (D)
print(f"Amplitude total: {(dados.max() - dados.min())[0]}")
print(f"Variância: {np.var(dados_cont)}")
print(f"Desvio padrão: {dados.std()[0]}")
print(f"Coeficiente de covariância: {(dados.std() / dados.mean())[0] * 100}%")

# As medidas são de alta dispersão

# %%
# Questão 2 (A)
dados_cont = np.array(
    ['A', 'B', 'D', 'A', 'A', 'F', 'C', 'A', 'C', 'B', 'E', 'B', 'A', 'C', 'F', 'D', 'B', 'C', 'D', 'A', 'A',
     'C', 'B', 'E', 'B', 'C', 'E', 'A', 'B', 'A', 'A', 'A', 'B', 'C', 'C', 'D', 'F', 'D', 'B', 'B', 'A', 'F',
     'C', 'B', 'A', 'C', 'B', 'E', 'E', 'D', 'A', 'B', 'C', 'E', 'A', 'A', 'F', 'C', 'B', 'D', 'D', 'D', 'B',
     'D', 'C', 'A', 'F', 'A', 'A', 'B', 'D', 'E', 'A', 'E', 'D', 'B', 'C', 'A', 'F', 'A', 'C', 'D', 'D', 'A',
     'A', 'B', 'A', 'F', 'D', 'C', 'A', 'C', 'B', 'F', 'D', 'A', 'E', 'A', 'C', 'D'])
dados = pd.DataFrame.from_dict({'dados': dados_cont})
frequencia_absoluta = dados.value_counts()
frequencia_relativa = dados.value_counts(normalize=True) * 100
print(frequencia_absoluta)
print(frequencia_relativa)
# Out:
# dados
# A        28
# B        19
# C        18
# D        17
# E         9
# F         9
# dtype: int64
# dados
# A        28.0
# B        19.0
# C        18.0
# D        17.0
# E         9.0
# F         9.0
# dtype: float64

# %%
# Questão 2 (B)
labels, counts = np.unique(dados_cont, return_counts=True)
ticks = range(len(counts))
plt.bar(ticks, counts, align='center')
plt.xticks(ticks, labels)
plt.show()

plt.pie(frequencia_relativa, labels=['A', 'B', 'C', 'D', 'E', 'F'])
plt.show()

# %%
# Questão 2 (C)
print("O acidente com maior frequência é o acidente A, enquanto o com menor frequência são os acidentes E e F.")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [43], line 7
#       2 dados_cont = {
#       3     'A': [6, 14, 23, 24, 6, 26, 22, 5, 28, 21, 20, 29, 18, 26, 14, 24, 19, 6, 12, 7],
#       4     'B': [2, 6, 0, 30, 4, 27, 30, 12, 21, 11, 26, 15, 0, 26, 15, 14, 17, 18, 25, 7]
#       5 }
#       6 dados = pd.DataFrame.from_dict(dados_cont)
# ----> 7 dados['A'].index.freq
#
# AttributeError: 'RangeIndex' object has no attribute 'freq'

# %%
# Out:
# O acidente com maior frequência é o acidente A, enquanto o com menor frequência são os acidentes E e F.

# %%
# Questão 3 (A)
dados_cont = {
    'A': [6, 14, 23, 24, 6, 26, 22, 5, 28, 21, 20, 29, 18, 26, 14, 24, 19, 6, 12, 7],
    'B': [2, 6, 0, 30, 4, 27, 30, 12, 21, 11, 26, 15, 0, 26, 15, 14, 17, 18, 25, 7]
}
dados = pd.DataFrame.from_dict(dados_cont)
total_a = sum(dados['A'])

for i, dado in dados['A'].enumerate():
    print(f"{dado / total_a}% dos anúncios foram visualizados no dia {i + 1}")
# Out:
# 1.7142857142857144% dos anúncios foram visualizados no dia 1
# 4.0% dos anúncios foram visualizados no dia 2
# 6.571428571428571% dos anúncios foram visualizados no dia 3
# 6.857142857142858% dos anúncios foram visualizados no dia 4
# 1.7142857142857144% dos anúncios foram visualizados no dia 5
# 7.428571428571429% dos anúncios foram visualizados no dia 6
# 6.2857142857142865% dos anúncios foram visualizados no dia 7
# 1.4285714285714286% dos anúncios foram visualizados no dia 8
# 8.0% dos anúncios foram visualizados no dia 9
# 6.0% dos anúncios foram visualizados no dia 10
# 5.714285714285714% dos anúncios foram visualizados no dia 11
# 8.285714285714285% dos anúncios foram visualizados no dia 12
# 5.142857142857142% dos anúncios foram visualizados no dia 13
# 7.428571428571429% dos anúncios foram visualizados no dia 14
# 4.0% dos anúncios foram visualizados no dia 15
# 6.857142857142858% dos anúncios foram visualizados no dia 16
# 5.428571428571429% dos anúncios foram visualizados no dia 17
# 1.7142857142857144% dos anúncios foram visualizados no dia 18
# 3.428571428571429% dos anúncios foram visualizados no dia 19
# 2.0% dos anúncios foram visualizados no dia 20

# %%
# Questão 3 (B)
indices = np.arange(len(dados)) + 1 # Troca 0..19 por 1..20
plt.bar(indices - 0.2, dados_cont['A'], 0.4)
plt.bar(indices + 0.2, dados_cont['B'], 0.4)
plt.xticks(indices)
plt.xlabel('Dia')
plt.show()

# %%
# Questão 3 (C)
print(f"Média anúncio A: {dados['A'].mean()}")
print(f"Mediana anúncio A: {dados['A'].median()}")
print(f"Moda anúncio A: {dados['A'].mode()[0]}")
print()
print(f"Média anúncio B: {dados['B'].mean()}")
print(f"Mediana anúncio B {dados['B'].median()}")
print(f"Moda anúncio B {dados['B'].mode()[0]}")
# Out:
# Média anúncio A: 17.5
# Mediana anúncio A: 19.5
# Moda anúncio A: 6
#
# Média anúncio B: 15.3
# Mediana anúncio B 15.0
# Moda anúncio B 0

# %%
# Questão 3 (D)
plt.boxplot(dados, labels=['A', 'B'])

plt.show()

# %%
# Questão 3 (D)
covariancia_a = dados['A'].std() / dados['A'].mean()
amplitude_a = dados['A'].max() - dados['A'].min()
print(f"A amplitude do anúncio A: {amplitude_a}")
print(f"Variância do anúncio A: {np.var(dados_cont['A'])}")
print(f"Coeficiente de covariância do anúncio A: {covariancia_a * 100}%")
print()
covariancia_b = dados['B'].std() / dados['B'].mean()
amplitude_b = dados['B'].max() - dados['B'].min()
print(f"A amplitude do anúncio B: {amplitude_b}")
print(f"Variância do anúncio B: {np.var(dados_cont['B'])}")
print(f"Coeficiente de covariância do anúncio B: {covariancia_b * 100}%")
# Out:
# A amplitude do anúncio A: 24
# Variância do anúncio A: 63.05
# Coeficiente de covariância do anúncio A: 46.55246627198495%
#
# A amplitude do anúncio B: 30
# Variância do anúncio B: 94.71000000000001
# Coeficiente de covariância do anúncio B: 65.2596416738104%
